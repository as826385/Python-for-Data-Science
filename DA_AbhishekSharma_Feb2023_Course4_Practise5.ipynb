# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('DS1_C4_S5_Employee_Data_Practice.xlsx')

# %% [markdown]
# ## Task1:

# %%
T1=pd.pivot_table(df,values='Annual Salary ($)',index='Department',aggfunc='sum')
T1
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
plt.bar(T1.index,T1['Annual Salary ($)'])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Task2:

# %%
T2=pd.crosstab(df.Department,df.Gender,rownames=['Department'],colnames=['Gender'])
T2
# Out:
# Gender      Female  Male
# Department
# Finance          2    11
# HR              11     4
# IT              10    12
# Sales            4    16

# %% [markdown]
# ## Task3:

# %%
T3=df[(df['Department']=='IT ')&(df['Work_Experience']==0)]
T3
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 7             1017    Male        IT               28000   23                0
# 12            1022    Male        IT               29000   22                0
# 46            1055    Male        IT               27500   22                0
# 47            1056  Female        IT               29000   23                0

# %%
T3_avg=T3['Annual Salary ($)'].mean()
print('The average salary of fresher in IT department is: ',T3_avg)
# Out:
# The average salary of fresher in IT department is:  28100.0

# %% [markdown]
# ## Task4:

# %%
T4=pd.pivot_table(df,values='Annual Salary ($)',index='Department',aggfunc='sum')
T4
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
plt.pie('Annual Salary ($)',labels=T4.index,data=T4,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a51d99c7f0>,
# ...
#  [Text(0.9089877668487375, 0.6194685139047388, 'Finance'),
#   Text(-0.400815236095585, 1.024376467180714, 'HR'),
#   Text(-0.9540753036420191, -0.5474854472772671, 'IT '),
#   Text(0.7467336367070757, -0.8077059339946842, 'Sales')],
#  [Text(0.4958115091902204, 0.337891916675312, '19.04%'),
#   Text(-0.21862649241577362, 0.5587508002803894, '23.79%'),
#   Text(-0.5204047110774649, -0.2986284257876002, '30.92%'),
#   Text(0.40730925638567766, -0.4405668730880095, '26.25%')])

# %% [markdown]
# ## Task5:

# %%
plt.hist(df['Age'])
# Out:
# (array([11., 17., 13., 10.,  3.,  5.,  3.,  3.,  3.,  2.]),
#  array([22. , 24.8, 27.6, 30.4, 33.2, 36. , 38.8, 41.6, 44.4, 47.2, 50. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Task6:

# %%
plt.scatter(data=df,x='Annual Salary ($)',y='Work_Experience')

# %% [markdown]
# ## Task7:

# %%
df['Department'].unique()
# Out:
# array(['IT ', 'Sales', 'Finance', 'HR'], dtype=object)

# %%
a=df.groupby('Department')

# %%
IT=a.get_group('IT ')
Sales=a.get_group('Sales')
Finance=a.get_group('Finance')
HR=a.get_group('HR')

# %%
IT_sal=IT.boxplot(column='Annual Salary ($)')

# %%
Sales_sal=Sales.boxplot(column='Annual Salary ($)')

# %%
Finance_sal=Finance.boxplot(column='Annual Salary ($)')

# %%
HR_sal=HR.boxplot(column='Annual Salary ($)')

# %% [markdown]
# ### IT and HR Departments each have 1 outliers
