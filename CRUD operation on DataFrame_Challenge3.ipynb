# %%
import pandas as pd

# %% [markdown]
# ## Task1:

# %%
data=pd.read_csv('DS1_C4_S3_Loan_Data_Challenge.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
data.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False       False             False
# ...

# %% [markdown]
# ## Task2:

# %%
data[(data['Gender']=='Female')&(data['Self_Employed']=='Yes')&(data['ApplicantIncome']>4000)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# ## Task3:

# %%
T3=data[(data['Gender']=='Male')&(data['Education']=='Graduate')&(data['Loan_Status']=='Y')]
T3
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
print('The count of these customers is: ',T3['Loan_ID'].size)
# Out:
# The count of these customers is:  279

# %% [markdown]
# ## Task4:

# %%
T4=data[(data['Loan_Status']=='Y')&(data['Dependents']>='3')&(data['Property_Area']=='Rural')]
T4
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %%
print('The count of these customers is: ',T4['Loan_ID'].size)
# Out:
# The count of these customers is:  13

# %% [markdown]
# ## Task5:

# %%
data[(data['LoanAmount']>=290)&(data['Education']=='Graduate')&(data['Property_Area']=='Urban')]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 21   LP001046    Male     Yes          1  Graduate            No
# 67   LP001233    Male     Yes          1  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 171  LP001585    Male     Yes         3+  Graduate            No
# 260  LP001865    Male     Yes          1  Graduate            No
# 333  LP002101    Male     Yes          0  Graduate            No
# 487  LP002547    Male     Yes          1  Graduate            No
# 506  LP002624    Male     Yes          0  Graduate            No
# 536  LP002734    Male     Yes          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 21              5955             5625.0         315               360
# 67             10750                0.0         312               360
# ...

# %%
#warner kim will get his loan approved because all other customers who have same conditions as warner got the loan.

# %% [markdown]
# ## Task6:

# %%
T6=data[(data['Married']=='No')&(data['Self_Employed']=='Yes')&(data['Property_Area']!='Urban')&(data['Loan_Status']=='N')]
T6
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0         106               360
# 107             7333                0.0         120               360
# 286             2600             1717.0          99               300
# 404             7441                0.0         194               360
# ...

# %%
T6['Gender'].value_counts()
# Out:
# Female    4
# Male      3
# Name: Gender, dtype: int64

# %% [markdown]
# ## Task7:

# %%
u=data[(data['Property_Area']=='Urban')]
r=data[(data['Property_Area']=='Rural')]
su=data[(data['Property_Area']=='Semiurban')]

# %%
print('Average income of customers in Urban areas is: ',u['ApplicantIncome'].mean())
# Out:
# Average income of customers in Urban areas is:  5398.247524752475

# %%
print('Average income of customers in Rural areas is: ',r['ApplicantIncome'].mean())
# Out:
# Average income of customers in Rural areas is:  5554.083798882682

# %%
print('Average income of customers in Semiurban areas is: ',su['ApplicantIncome'].mean())
# Out:
# Average income of customers in Semiurban areas is:  5292.261802575107

# %% [markdown]
# ## Task8:

# %%
T8=data[(data['Property_Area'].isin(['Rural','Semiurban']))&(data['ApplicantIncome']>4000)&(data['CoapplicantIncome']>1000)&(data['Loan_Status']=='N')]
T8
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %%
print('The number of these customers is: ',T8['Loan_ID'].size)
# Out:
# The number of these customers is:  23

# %%
T8['Loan_Status']='Y'
# Out:
# C:\Users\as826\AppData\Local\Temp\ipykernel_7368\758204741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   T8['Loan_Status']='Y'

# %%
data.update(T8[['Loan_Status']])

# %%
data[(data['Property_Area'].isin(['Rural','Semiurban']))&(data['ApplicantIncome']>4000)&(data['CoapplicantIncome']>1000)&(data['Loan_Status']=='N')]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %% [markdown]
# ## Task9:

# %%
T9=data[(data['Loan_Status']=='Y')&(data['Dependents']>='3')&(data['Property_Area']=='Urban')]
T9
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 61   LP001206   Male     Yes         3+      Graduate            No
# 68   LP001238   Male     Yes         3+  Not Graduate           Yes
# 171  LP001585   Male     Yes         3+      Graduate            No
# 267  LP001882   Male     Yes         3+      Graduate            No
# 295  LP001949   Male     Yes         3+      Graduate            No
# 461  LP002484   Male     Yes         3+      Graduate            No
# 531  LP002720   Male     Yes         3+      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 61              3029                0.0          99               360
# 68              7100                0.0         125                60
# 171            51763                0.0         700               300
# 267             4333             1811.0         160               360
# ...

# %%
print('The count os these customers is: ',T9['Loan_ID'].size)
# Out:
# The count os these customers is:  8

# %%
print('The average income of these customers is: ',T9['ApplicantIncome'].mean())
# Out:
# The average income of these customers is:  11045.625

# %% [markdown]
# ## Task10:

# %%
T10=data[data['Property_Area']=='Urban']
avg_urban=T10['ApplicantIncome'].mean()

# %%
data[(data['Property_Area'].isin(['Rural','Semiurban']))&(data['Dependents']>='3')&(data['ApplicantIncome']>avg_urban)]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 34   LP001100   Male      No         3+      Graduate            No
# 126  LP001448   Male     Yes         3+      Graduate            No
# 155  LP001536   Male     Yes         3+      Graduate            No
# 177  LP001610   Male     Yes         3+      Graduate            No
# 213  LP001715   Male     Yes         3+  Not Graduate           Yes
# 324  LP002065   Male     Yes         3+      Graduate            No
# 376  LP002219   Male     Yes         3+      Graduate            No
# 390  LP002255   Male      No         3+      Graduate            No
# 391  LP002262   Male     Yes         3+      Graduate            No
# 409  LP002317   Male     Yes         3+      Graduate            No
# 522  LP002692   Male     Yes         3+      Graduate           Yes
# 539  LP002740   Male     Yes         3+      Graduate            No
# 557  LP002795   Male     Yes         3+      Graduate           Yes
# ...

# %%
#i infer that data analytics is everywhere and without analytics bank will also face a major problem in approving loans. Analytics makes our decision making easy and saves us lot of time

# %%
T11=data[(data['Property_Area']!='Urban')&(data['Loan_Status']=='Y')]

# %%
print('The average income of above given condition fulfilling applicants is: ',T11['ApplicantIncome'].mean())
# Out:
# The average income of above given condition fulfilling applicants is:  5332.445512820513
