# %%
import pandas as pd

# %% [markdown]
# ## Task1:

# %%
df=pd.read_csv('DS1_C4_S4_Test_Scores_Data_Practice.csv')
df
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
df.isnull().sum()
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 4
# test2                 4
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      1071
# Female    1052
# Name: gender, dtype: int64

# %%
df['gender'].fillna('Male',inplace=True)

# %%
df['test1'].mean()
# Out:
# 54.96195396899953

# %%
df['test1'].fillna(55,inplace=True)

# %%
df['test2'].mean()
# Out:
# 67.11131986848285

# %%
df['test2'].fillna(67,inplace=True)

# %%
df.isnull().sum()
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                0
# test2                0
# dtype: int64

# %% [markdown]
# ## Task2:

# %%
df1=df.loc[:,df.columns!='student_id']

# %%
df_dup=df1[df1.duplicated(keep='first')]

# %%
df=df.drop(df_dup.index)

# %%
df
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 5     ANKYI          Urban  Non-public       6OL        Standard      7YZO8
# ...     ...            ...         ...       ...             ...        ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard      S4I5S
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %% [markdown]
# ## task3:

# %%
df=df.replace(to_replace=['Does not qualify','Qualifies for reduced/free '],value=['No','Yes'])

# %%
df
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 5     ANKYI          Urban  Non-public       6OL        Standard      7YZO8
# ...     ...            ...         ...       ...             ...        ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard      S4I5S
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender tuitionfee_waiver  test1  test2
# ...

# %% [markdown]
# ## Task4:

# %%
avg_school=df.groupby('school')['test1'].mean()
avg_school
# Out:
# school
# ANKYI    61.263158
# CCAAW    64.707547
# CIMBB    65.069444
# CUQAM    53.866667
# DNQDD    54.275000
# FBUMG    62.891304
# GJJHK    53.236842
# GOKXL    50.888889
# GOOBU    38.430464
# IDGFP    75.279070
# KFZMY    41.900000
# KZKKE    37.461538
# LAYPA    62.035088
# OJOBU    56.202532
# QOQTS    52.647887
# UAGPU    62.452381
# UKPGS    78.537190
# UUUQX    67.012195
# VHDHF    52.666667
# VKWQH    52.151515
# VVTVA    36.186916
# ZMNYA    68.030303
# ZOWMK    41.603604
# Name: test1, dtype: float64

# %%
print('The school with highest average test score is: ',avg_school.idxmax())
# Out:
# The school with highest average test score is:  UKPGS

# %% [markdown]
# ## Task5:

# %%
T5=pd.pivot_table(df,values=['test2'],index='school',aggfunc=max)
T5
# Out:
#         test2
# school
# ANKYI    79.0
# CCAAW    91.0
# CIMBB    88.0
# CUQAM    76.0
# DNQDD    79.0
# FBUMG    88.0
# GJJHK    85.0
# GOKXL    77.0
# GOOBU    67.0
# IDGFP   100.0
# KFZMY    67.0
# KZKKE    62.0
# LAYPA    84.0
# OJOBU    84.0
# QOQTS    85.0
# UAGPU    83.0
# UKPGS    99.0
# UUUQX    91.0
# VHDHF    77.0
# VKWQH    82.0
# VVTVA    67.0
# ZMNYA    95.0
# ZOWMK    63.0

# %%
T5_dsc=T5.sort_values(by='test2',ascending=False)
T5_dsc.head()
# Out:
#         test2
# school
# IDGFP   100.0
# UKPGS    99.0
# ZMNYA    95.0
# CCAAW    91.0
# UUUQX    91.0

# %% [markdown]
# ## Task6:

# %%
T6=df[(df['school']=='FBUMG')&(df['classroom']=='5LQ')&(df['test2']>=80)]

# %%
T6s=pd.DataFrame([500]*len(T6.index))

# %%
T6=T6.reset_index(drop=True)

# %%
T6=pd.concat([T6,T6s],axis=1)

# %%
T6=T6.rename(columns={0:'Scholorship'})
T6
# Out:
#    school school_setting school_type classroom teaching_method student_id  \
# 0   FBUMG          Rural  Non-public       5LQ    Experimental      04DG5
# 1   FBUMG          Rural  Non-public       5LQ    Experimental      20M2D
# 2   FBUMG          Rural  Non-public       5LQ    Experimental      39KCW
# 3   FBUMG          Rural  Non-public       5LQ    Experimental      5Z1B6
# 4   FBUMG          Rural  Non-public       5LQ    Experimental      6TLU8
# 5   FBUMG          Rural  Non-public       5LQ    Experimental      ATQQJ
# 6   FBUMG          Rural  Non-public       5LQ    Experimental      B9FSU
# 7   FBUMG          Rural  Non-public       5LQ    Experimental      EV13K
# 8   FBUMG          Rural  Non-public       5LQ    Experimental      I5H37
# 9   FBUMG          Rural  Non-public       5LQ    Experimental      JC5I9
# 10  FBUMG          Rural  Non-public       5LQ    Experimental      JPE2J
# 11  FBUMG          Rural  Non-public       5LQ    Experimental      MFBYU
# ...

# %% [markdown]
# ## Task7:

# %%
T7=pd.crosstab(df.school_setting,df.teaching_method,rownames=['school_setting'],colnames=['teaching_method'])
T7
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     199       300
# Suburban                  273       420
# Urban                     263       599

# %% [markdown]
# ## Task8:

# %%
T8=pd.crosstab(df.school_setting,df.gender,rownames=['school_setting'],colnames=['gender'])
T8
# Out:
# gender          Female  Male
# school_setting
# Rural              223   276
# Suburban           354   339
# Urban              430   432

# %% [markdown]
# ## Task9:

# %%
T9=pd.pivot_table(df,values='test2',index='school_setting',columns='gender',aggfunc='mean')
T9
# Out:
# gender             Female       Male
# school_setting
# Rural           64.367713  64.304348
# Suburban        75.875706  75.988201
# Urban           61.237209  62.331019
