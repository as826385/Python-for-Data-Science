# %%
import pandas as pd

# %%
data=pd.read_csv('DS1_C4_S3_SalesData_Practice.csv')
data
# Out:
#    Month Store  Sales       State
# 0    Jan     A  21080      Alaska
# 1    Jan     B  32985       Texas
# 2    Jan     C  22369  California
# 3    Jan     D  45710     Montana
# 4    Jan     E  27113  New Mexico
# 5    Feb     A  27573      Alaska
# 6    Feb     B  31244       Texas
# 7    Feb     C  48624  California
# 8    Feb     D  31768     Montana
# 9    Feb     E  23851  New Mexico
# 10   Mar     A  33274      Alaska
# 11   Mar     B  27215       Texas
# 12   Mar     C  23475  California
# 13   Mar     D  21357     Montana
# 14   Mar     E  22130  New Mexico
# 15   Apr     A  26073      Alaska
# 16   Apr     B  45919       Texas
# 17   Apr     C  30279  California
# 18   Apr     D  21394     Montana
# 19   Apr     E  25184  New Mexico
# 20   May     A  37649      Alaska
# 21   May     B  44597       Texas
# 22   May     C  29697  California
# 23   May     D  28943     Montana
# 24   May     E  22541  New Mexico
# 25   Jun     A  28500      Alaska
# ...

# %% [markdown]
# ### Task1:

# %%
asc_sales=data.sort_values('Sales',ascending=False)
asc_sales
# Out:
#    Month Store  Sales       State
# 7    Feb     C  48624  California
# 16   Apr     B  45919       Texas
# 3    Jan     D  45710     Montana
# 21   May     B  44597       Texas
# 29   Jun     E  41098  New Mexico
# 20   May     A  37649      Alaska
# 28   Jun     D  37098     Montana
# 10   Mar     A  33274      Alaska
# 1    Jan     B  32985       Texas
# 26   Jun     B  32896       Texas
# 8    Feb     D  31768     Montana
# 6    Feb     B  31244       Texas
# 17   Apr     C  30279  California
# 27   Jun     C  30200  California
# 22   May     C  29697  California
# 23   May     D  28943     Montana
# 25   Jun     A  28500      Alaska
# 5    Feb     A  27573      Alaska
# 11   Mar     B  27215       Texas
# 4    Jan     E  27113  New Mexico
# 15   Apr     A  26073      Alaska
# 19   Apr     E  25184  New Mexico
# 9    Feb     E  23851  New Mexico
# 12   Mar     C  23475  California
# 24   May     E  22541  New Mexico
# 2    Jan     C  22369  California
# ...

# %% [markdown]
# ### Task2:

# %%
T2=data[data['Sales']>=45000]
T2
# Out:
#    Month Store  Sales       State
# 3    Jan     D  45710     Montana
# 7    Feb     C  48624  California
# 16   Apr     B  45919       Texas

# %% [markdown]
# ### Task3:

# %%
C=data[data.State=='California']
Cs=C.sort_values('Sales')
Cs
# Out:
#    Month Store  Sales       State
# 2    Jan     C  22369  California
# 12   Mar     C  23475  California
# 22   May     C  29697  California
# 27   Jun     C  30200  California
# 17   Apr     C  30279  California
# 7    Feb     C  48624  California

# %%
T=data[data.State=='Texas']
Ts=T.sort_values('Sales')
Ts
# Out:
#    Month Store  Sales  State
# 11   Mar     B  27215  Texas
# 6    Feb     B  31244  Texas
# 26   Jun     B  32896  Texas
# 1    Jan     B  32985  Texas
# 21   May     B  44597  Texas
# 16   Apr     B  45919  Texas

# %%
M=data[data.State=='Montana']
Ms=M.sort_values('Sales')
Ms
# Out:
#    Month Store  Sales    State
# 13   Mar     D  21357  Montana
# 18   Apr     D  21394  Montana
# 23   May     D  28943  Montana
# 8    Feb     D  31768  Montana
# 28   Jun     D  37098  Montana
# 3    Jan     D  45710  Montana

# %% [markdown]
# ### Task4:

# %%
print('Total sales of California is: ',C.Sales.sum())
# Out:
# Total sales of California is:  184644

# %%
print("Total sales of Texas is: ",T.Sales.sum())
# Out:
# Total sales of Texas is:  214856

# %%
print('Total sales of Montana is: ',M.Sales.sum())
# Out:
# Total sales of Montana is:  186270

# %% [markdown]
# ### Task5:

# %%
Lowest=Cs.head(1)
Lowest
# Out:
#   Month Store  Sales       State
# 2   Jan     C  22369  California

# %%
Highest=Cs.tail(1)
Highest
# Out:
#   Month Store  Sales       State
# 7   Feb     C  48624  California

# %% [markdown]
# ### Task6:

# %%
d1=data.groupby('State')['Sales'].sum()
D1=pd.DataFrame(d1)
D1
# Out:
#              Sales
# State
# Alaska      174149
# California  184644
# Montana     186270
# New Mexico  161917
# Texas       214856

# %% [markdown]
# ### Task7:

# %%
T7=D1.sort_values('Sales')
T7
# Out:
#              Sales
# State
# New Mexico  161917
# Alaska      174149
# California  184644
# Montana     186270
# Texas       214856

# %%
T7.to_csv('Total_sales.csv',index=True)
