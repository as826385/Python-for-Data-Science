# %% [markdown]
# ## Task1:

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df=pd.read_csv('DS1_C4_S7_Car_Data_Challenge.csv')

# %%
T1=df[['Cylinders','Kerb_Weight','Make','Displacement','Fuel_Tank_Capacity_litre','City_Mileage_km_litre','Highway_Mileage_km_litre','Power','Torque']]

# %%
T1.dropna(inplace=True)
T1
# Out:
#       Cylinders Kerb_Weight           Make  Displacement  \
# 24          4.0      920 kg  Maruti Suzuki        1196.0
# 25          4.0      940 kg  Maruti Suzuki        1196.0
# 26          4.0      928 kg  Maruti Suzuki        1196.0
# 29          3.0      745 kg  Maruti Suzuki         998.0
# 30          3.0      750 kg  Maruti Suzuki         998.0
# ...         ...         ...            ...           ...
# 1270        4.0     1170 kg          Honda        1498.0
# 1271        4.0     1175 kg          Honda        1498.0
# 1272        4.0     1107 kg          Honda        1497.0
# 1273        4.0     1080 kg          Honda        1497.0
# 1274        4.0     2335 kg     Mitsubishi        3200.0
#
#       Fuel_Tank_Capacity_litre  City_Mileage_km_litre  \
# 24                        40.0                  12.00
# 25                        40.0                  12.00
# 26                        40.0                  11.00
# 29                        35.0                  14.00
# ...

# %% [markdown]
# ## Task2:

# %%
df['Kerb_Weight']=df['Kerb_Weight'].str.replace('kg','').str.replace('-','')
df['Kerb_Weight']=pd.to_numeric(df['Kerb_Weight'])
df['Kerb_Weight']=df['Kerb_Weight']*2.2
df[['Kerb_Weight']]
# Out:
#       Kerb_Weight
# 0          1452.0
# 1          1595.0
# 2          1562.0
# 3          1595.0
# 4          1595.0
# ...           ...
# 1270       2574.0
# 1271       2585.0
# 1272       2435.4
# 1273       2376.0
# 1274       5137.0
#
# [1275 rows x 1 columns]

# %%
df['Power']=df['Power'].str.extract('(\d+)')
df['Power']=pd.to_numeric(df['Power'])
df[['Power']]
# Out:
#       Power
# 0        38
# 1        38
# 2        38
# 3        38
# 4        38
# ...     ...
# 1270    100
# 1271    100
# 1272    119
# 1273    119
# 1274    202
#
# [1275 rows x 1 columns]

# %%
df['Torque']=df['Torque'].str.extract('(\d+)')
df['Torque']=pd.to_numeric(df['Torque'])
df[['Torque']]
# Out:
#       Torque
# 0       51.0
# 1       51.0
# 2       51.0
# 3       51.0
# 4       51.0
# ...      ...
# 1270   200.0
# 1271   200.0
# 1272   145.0
# 1273   145.0
# 1274   441.0
#
# [1275 rows x 1 columns]

# %% [markdown]
# ## Task3:

# %%
T1['Power']=df[['Power']]
T1['Torque']=df[['Torque']]

# %%
T3_mean=T1.groupby(by='Make')['Cylinders','Kerb_Weight','Displacement','Fuel_Tank_Capacity_litre','City_Mileage_km_litre','Highway_Mileage_km_litre','Power','Torque'].mean()
T3_mean
# Out:
#                   Cylinders  Displacement  Fuel_Tank_Capacity_litre  \
# Make
# Aston Martin      10.000000   4958.500000                 81.750000
# Audi               6.285714   3147.714286                 67.857143
# Bentley           10.400000   5738.200000                 89.000000
# Bmw                4.857143   2419.142857                 64.714286
# Dc                 4.000000   2000.000000                 60.000000
# Ferrari            8.000000   4011.600000                 84.000000
# Fiat               4.000000   1273.818182                 45.000000
# Ford               4.333333   2531.333333                 80.000000
# Honda              4.000000   1523.473684                 41.894737
# Hyundai            4.000000   1252.277778                 44.333333
# Icml               4.000000   1994.000000                 50.000000
# Jaguar             4.750000   2371.750000                 77.250000
# Lamborghini       12.000000   6498.000000                 90.000000
# ...

# %%
T1_median=T1.groupby(by='Make')['Cylinders','Kerb_Weight','Displacement','Fuel_Tank_Capacity_litre','City_Mileage_km_litre','Highway_Mileage_km_litre','Power','Torque'].median()
T1_median
# Out:
#                   Cylinders  Displacement  Fuel_Tank_Capacity_litre  \
# Make
# Aston Martin           10.0        4958.5                     81.75
# Audi                    6.0        2967.0                     75.00
# Bentley                12.0        5998.0                     90.00
# Bmw                     4.0        1998.0                     67.00
# Dc                      4.0        2000.0                     60.00
# Ferrari                 8.0        3902.0                     86.00
# Fiat                    4.0        1248.0                     45.00
# Ford                    4.0        2198.0                     80.00
# Honda                   4.0        1497.0                     40.00
# Hyundai                 4.0        1197.0                     45.00
# Icml                    4.0        1994.0                     50.00
# Jaguar                  4.0        1999.0                     82.00
# Lamborghini            12.0        6498.0                     90.00
# ...

# %%
T1_std=T1.groupby(by='Make')['Cylinders','Kerb_Weight','Displacement','Fuel_Tank_Capacity_litre','City_Mileage_km_litre','Highway_Mileage_km_litre','Power','Torque'].std()
T1_std
# Out:
#                   Cylinders  Displacement  Fuel_Tank_Capacity_litre  \
# Make
# Aston Martin       2.828427   1380.979544                 12.374369
# Audi               2.138090   1141.945958                 12.198751
# Bentley            2.190890   1031.184368                  2.236068
# Bmw                1.069045    528.085356                  6.524678
# Dc                      NaN           NaN                       NaN
# Ferrari            0.000000    272.108986                  6.000000
# Fiat               0.000000     64.531881                  0.000000
# Ford               0.577350    577.350269                  0.000000
# Honda              0.000000    113.702032                  4.495612
# Hyundai            0.000000     91.716831                  0.970143
# Icml               0.000000      0.000000                  0.000000
# Jaguar             1.035098    514.443874                  7.535630
# Lamborghini        0.000000      0.000000                  0.000000
# ...

# %%
T1_cov=(T1.groupby(by='Make')['Cylinders','Kerb_Weight','Displacement','Fuel_Tank_Capacity_litre','City_Mileage_km_litre','Highway_Mileage_km_litre','Power','Torque'].std()/T1.groupby(by='Make')['Cylinders','Kerb_Weight','Displacement','Fuel_Tank_Capacity_litre','City_Mileage_km_litre','Highway_Mileage_km_litre','Power','Torque'].mean())*100
T1_cov
# Out:
#                   Cylinders  Displacement  Fuel_Tank_Capacity_litre  \
# Make
# Aston Martin      28.284271     27.850752                 15.136842
# Audi              34.015067     36.278577                 17.977107
# Bentley           21.066252     17.970520                  2.512436
# Bmw               22.009749     21.829441                 10.082285
# Dc                      NaN           NaN                       NaN
# Ferrari            0.000000      6.783054                  7.142857
# Fiat               0.000000      5.066020                  0.000000
# Ford              13.323468     22.808149                  0.000000
# Honda              0.000000      7.463341                 10.730732
# Hyundai            0.000000      7.324001                  2.188291
# Icml               0.000000      0.000000                  0.000000
# Jaguar            21.791544     21.690476                  9.754860
# Lamborghini        0.000000      0.000000                  0.000000
# ...

# %%
import matplotlib.pyplot as plt
T1.boxplot(by='Make',column='Displacement',figsize=(15,9))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Task4:

# %%
T4=df[(df['Make']=='Renault')|(df['Make']=='Toyota') |(df['Make']=='Honda')]

# %%
import seaborn as sns
sns.regplot(x=T4['Displacement'],y=T4['City_Mileage_km_litre'])
plt.title('Relationship between Displacement and City Mileage')
# Out:
# Text(0.5, 1.0, 'Relationship between Displacement and City Mileage')

# %% [markdown]
# ###### In the above case more displacement will effect car mileage negatively and less displacement will have positive effect on mileage

# %%
sns.regplot(x=T4['Torque'],y=T4['City_Mileage_km_litre'])
plt.title('Relationship between Torque and City Mileage')
# Out:
# <AxesSubplot:xlabel='Torque', ylabel='City_Mileage_km_litre'>

# %% [markdown]
# ###### In case of Torque also - More Torque means less mileage and less Torque means more mileage

# %%
sns.regplot(x=T4['Power'],y=T4['City_Mileage_km_litre'])
plt.title('Relationship between Power and City Mileage')
# Out:
# Text(0.5, 1.0, 'Relationship between Power and City Mileage')

# %% [markdown]
# ###### Power also plays the same role in cars mileage- less power means efficient mileage and more power means reduction in mileage.
